# %% [markdown]
# # Asistencias
#
# En este módulo se analizan asistencias usando listas, diccionarios, porcentajes y condicionales.

# %% [markdown]
# ## Representación de asistencias
#
# Usaremos listas con `1` y `0`.
#
# ```python
# 1 = asistió
# 0 = faltó
# ```
#
# Ejemplo:
#
# ```python
# [1, 1, 0, 1]
# ```

# %% [markdown]
# ## Función 15: `contar_clases(asistencias_alumno)`
#
# **Archivo:** `src/asistencias.py`
#
# Cuenta cuántas clases están registradas para un alumno.
#
# **Entrada:**
#
# ```python
# [1, 1, 0, 1]
# ```
#
# **Salida esperada:**
#
# ```python
# 4
# ```
#
# **Caso especial:**
#
# ```python
# [] -> 0
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_15_contar_clases.py
# ```

# %% [markdown]
# ## Función 16: `contar_asistencias(asistencias_alumno)`
#
# **Archivo:** `src/asistencias.py`
#
# Cuenta cuántas veces aparece `1`.
#
# **Entrada:**
#
# ```python
# [1, 1, 0, 1]
# ```
#
# **Salida esperada:**
#
# ```python
# 3
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_16_contar_asistencias.py
# ```

# %% [markdown]
# ## Función 17: `contar_faltas(asistencias_alumno)`
#
# **Archivo:** `src/asistencias.py`
#
# Cuenta cuántas veces aparece `0`.
#
# **Entrada:**
#
# ```python
# [1, 1, 0, 1]
# ```
#
# **Salida esperada:**
#
# ```python
# 1
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_17_contar_faltas.py
# ```

# %% [markdown]
# ## Función 18: `porcentaje_asistencia(asistencias_alumno)`
#
# **Archivo:** `src/asistencias.py`
#
# Calcula el porcentaje de asistencia de un alumno.
#
# El resultado debe estar en escala de `0` a `100`.
#
# **Entrada:**
#
# ```python
# [1, 1, 0, 1]
# ```
#
# **Salida esperada:**
#
# ```python
# 75.0
# ```
#
# **Caso especial:**
#
# ```python
# [] -> 0.0
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_18_porcentaje_asistencia.py
# ```

# %% [markdown]
# ## Función 19: `esta_en_riesgo(asistencias_alumno)`
#
# **Archivo:** `src/asistencias.py`
#
# Regresa `True` si el porcentaje de asistencia es menor a `80`.
#
# **Entradas y salidas esperadas:**
#
# ```python
# [1, 1, 0, 1] -> True
# [1, 1, 1, 1] -> False
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_19_esta_en_riesgo.py
# ```

# %% [markdown]
# ## Función 20: `alumnos_en_riesgo(asistencias)`
#
# **Archivo:** `src/asistencias.py`
#
# Recibe un diccionario donde cada clave es el nombre de un alumno y cada valor es una lista con sus asistencias.
#
# Regresa una lista con los alumnos cuyo porcentaje de asistencia sea menor a `80`.
#
# **Entrada:**
#
# ```python
# {
#     "Ana": [1, 1, 1, 1],
#     "Luis": [1, 0, 0, 1],
#     "María": [1, 1, 1, 0]
# }
# ```
#
# **Salida esperada:**
#
# ```python
# ["Luis", "María"]
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_20_alumnos_en_riesgo.py
# ```

# %% [markdown]
# ## Función 21: `promedio_asistencia_grupo(asistencias)`
#
# **Archivo:** `src/asistencias.py`
#
# Calcula el promedio general de asistencia del grupo.
#
# **Entrada:**
#
# ```python
# {
#     "Ana": [1, 1, 1, 1],
#     "Luis": [1, 0, 0, 1]
# }
# ```
#
# **Salida esperada:**
#
# ```python
# 75.0
# ```
#
# **Explicación:**
#
# - Ana tiene 100%
# - Luis tiene 50%
# - El promedio del grupo es 75%
#
# **Caso especial:**
#
# ```python
# {} -> 0.0
# ```
#
# **Test:**
#
# ```bash
# python -m unittest tests/test_21_promedio_asistencia_grupo.py
# ```
